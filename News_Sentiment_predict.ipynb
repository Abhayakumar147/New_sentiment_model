# %%
import pandas as pd
import csv
from imblearn.over_sampling import SMOTE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import HashingVectorizer
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
from joblib import load
# Load the trained model
logistic_vanilla = load('logistic_vanilla.joblib')
tfidf_vectorizer = load('tfidf_vectorizer.joblib')
logistic_vanilla_source_map = load('logistic_vanilla_source_map.joblib')
tfidf_vectorizer_source_map = load('tfidf_vectorizer_source_map.joblib')
# Now you can use 'logistic_vanilla' for predictions

# %%
def read_data(csv_file):
    data =[]
    with open(csv_file, 'r', encoding='utf-8') as file:
        reader = csv.reader(file)
        for row in reader:
            data.append(row)
    header = data[0]
    # Create DataFrame from the remaining rows (excluding the header row)
    df = pd.DataFrame(data[1:], columns=header)
    df.rename(columns={header[0]: 'Bookmark'}, inplace=True)
    return df

# %%
csv_file = "C:\\Users\\tkaly\\lucky\\Hands_on_pratice\\News_sentiment\\news_2024-02-18_00-03-46.csv"
test_data = read_data(csv_file)
test_data.head()
# Out:
#   Bookmark Datetime Summary Sentiment  \
# 0       No  57:39.6              0.99
# 1       No  57:39.6             -0.98
# 2       No  57:39.6              0.97
# 3       No  57:39.6             -0.99
# 4       No  57:39.6              0.98
#
#                                             Headline  \
# 0  Kamal Haasan unveils Sivakarthikeyan-Sai Palla...
# 1  India sends relief material to cholera-affecte...
# 2  Not a surveillance satellite: ISRO on collabor...
# 3  Farmers' protest: Haryana extends mobile inter...
# 4  Hold LS, assembly polls together but not with ...
#
#                                              Summary   Source
# 0  This week, the teaser of Sivakarthikeyan's Tam...  Zerodha
# 1  The aid weighing approx 3.5 tons comprises wat...  Zerodha
# 2  The Bengaluru-headquartered ISRO is involved w...  Zerodha
# 3  Protesting farmers have stayed put at Shambhu ...  Zerodha
# 4  In a memorandum submitted to the committee, JD...  Zerodha

# %%
def predict_bookmark(test_data):
    # Preprocess the text data
    X_text_test = test_data[['Summary', 'Headline', 'Source']].astype(str).apply(lambda x: ' '.join(x), axis=1)
    X_text_test_tfidf = tfidf_vectorizer.transform(X_text_test)
    # Concatenate TF-IDF features with Sentiment feature
    X_test_processed = pd.concat([pd.DataFrame(X_text_test_tfidf.toarray()), test_data['Summary Sentiment']], axis=1)
    # Make predictions
    predictions = logistic_vanilla_source_map.predict(X_test_processed)
    # Add predicted class to the DataFrame
    test_data['Predicted_bookmark'] = predictions
    return test_data

# %%
predict_data = predict_bookmark(test_data)
# Out:
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
display(predict_data)
# Out:
#     Bookmark          Datetime Summary Sentiment  \
# 0         No           57:39.6              0.99
# 1         No           57:39.6             -0.98
# 2         No           57:39.6              0.97
# 3         No           57:39.6             -0.99
# 4         No           57:39.6              0.98
# ..       ...               ...               ...
# 240       No  16/02/2024 10:19             -0.96
# 241       No  16/02/2024 10:18             -0.99
# 242       No  16/02/2024 10:18             -0.99
# 243      Yes  16/02/2024 10:18              0.99
# 244      Yes  16/02/2024 10:18               0.6
#
#                                               Headline  \
# 0    Kamal Haasan unveils Sivakarthikeyan-Sai Palla...
# 1    India sends relief material to cholera-affecte...
# 2    Not a surveillance satellite: ISRO on collabor...
# 3    Farmers' protest: Haryana extends mobile inter...
# 4    Hold LS, assembly polls together but not with ...
# ..                                                 ...
# 240  Sensex, Nifty rise on positive global cues; an...
# 241  Entero Healthcare Solutions off to a weak star...
# 242  Gujarat Gas falls 6% as brokerages turn bearis...
# 243         HDFC net profit surges over 220% YoY in Q3
# 244         HDFC net profit surges over 220% YoY in Q3
#
#                                                Summary         Source  \
# 0    This week, the teaser of Sivakarthikeyan's Tam...        Zerodha
# 1    The aid weighing approx 3.5 tons comprises wat...        Zerodha
# 2    The Bengaluru-headquartered ISRO is involved w...        Zerodha
# 3    Protesting farmers have stayed put at Shambhu ...        Zerodha
# 4    In a memorandum submitted to the committee, JD...        Zerodha
# ..                                                 ...            ...
# 240  Experts expect markets to behave in a range-bo...  Money Control
# 241  Entero Healthcare Solutions IPO: The shares op...  Money Control
# 242  Volumes were impacted by a further market shar...  Money Control
# 243  EBITDA surged 30.9% to Rs 645 Crores, with EBI...  Money Control
# 244  EBITDA surged 30.9% to Rs 645 Crores, with EBI...        Zerodha
#
#      Predicted_bookmark
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 240                   0
# 241                   0
# 242                   0
# 243                   1
# 244                   1
#
# [245 rows x 7 columns]

# %%
def predict_bookmark_source_map(test_data):
    # Preprocess the text data
    X_text_test = test_data[['Summary', 'Headline',]].astype(str).apply(lambda x: ' '.join(x), axis=1)
    X_text_test_tfidf = tfidf_vectorizer_source_map.transform(X_text_test)
    test_data['Source'] = test_data['Source'].map({'Zerodha': 0, 'Money Control': 1, 'Economic Times': 2})
    # Concatenate TF-IDF features with Sentiment feature
    X_test_processed = pd.concat([pd.DataFrame(X_text_test_tfidf.toarray()), test_data[['Summary Sentiment', 'Source']]], axis=1)
    # Make predictions
    predictions = logistic_vanilla_source_map.predict(X_test_processed)
    # Add predicted class to the DataFrame
    test_data['Predicted_bookmark'] = predictions
    return test_data

# %%
Pred_source = predict_bookmark_source_map(test_data)
# Out:
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5744\2169758719.py in <module>
#       1 param_test1 = {'n_estimators':range(10,400,10)}
#       2 from sklearn.model_selection import GridSearchCV
# ----> 3 CV_gbc = GridSearchCV(estimator=gbc, param_grid=param_test1, scoring='roc_auc',n_jobs=4, cv= 5)
#       4 CV_gbc.fit(X_train_resampled,y_train_resampled)
#       5 CV_gbc.best_params_, CV_gbc.best_score_
#
# NameError: name 'gbc' is not defined
